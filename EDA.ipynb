# %%
import pandas as pd
import pyspark
import mlxtend
import pymongo
import sqlalchemy
import airflow
import numpy
import matplotlib
import sklearn
import os
import openpyxl

# %%
df = pd.read_excel("OnlineRetail.xlsx", engine="openpyxl")
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Load the XLSX file
file_path = "OnlineRetail.xlsx"
df = pd.read_excel(file_path, engine="openpyxl")

# Convert 'InvoiceNo' and 'StockCode' to string
df["InvoiceNo"] = df["InvoiceNo"].astype(str)
df["StockCode"] = df["StockCode"].astype(str)

# Handle missing values in 'Description' & convert to string
df["Description"] = df["Description"].fillna("Unknown").astype(str)

# Convert to Parquet (Optimized for Big Data)
output_parquet = "online_retail.parquet"
df.to_parquet(output_parquet, engine="pyarrow", index=False)

print(f"File converted and saved as {output_parquet}")
# Out:
# File converted and saved as online_retail.parquet

# %%
# Load the Parquet file
df = pd.read_parquet("online_retail.parquet")

# Display the first few rows
df.head(15)
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366     22633               HAND WARMER UNION JACK         6
# 8     536366     22632            HAND WARMER RED POLKA DOT         6
# 9     536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10    536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11    536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %%
from pyspark.sql import SparkSession

# Initialize Spark
spark = SparkSession.builder.appName("Ecommerce_Cleaning").getOrCreate()
# Out:
# The operation couldn’t be completed. Unable to locate a Java Runtime.
# Please visit http://www.java.com for information on installing Java.
#
# /opt/anaconda3/envs/datascience/lib/python3.8/site-packages/pyspark/bin/spark-class: line 97: CMD: bad array subscript
# head: illegal line count -- -1
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 4
#       1 from pyspark.sql import SparkSession
#       3 # Initialize Spark
# ----> 4 spark = SparkSession.builder.appName("Ecommerce_Cleaning").getOrCreate()
#
# File /opt/anaconda3/envs/datascience/lib/python3.8/site-packages/pyspark/sql/session.py:477, in SparkSession.Builder.getOrCreate(self)
#     475     sparkConf.set(key, value)
#     476 # This SparkContext may be an existing one.
# --> 477 sc = SparkContext.getOrCreate(sparkConf)
# ...
